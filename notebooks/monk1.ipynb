# %% [markdown]
# # MONK

# %%
import pandas as pd
import json
import numpy as np

with open("../results/monk1.json", "r") as fp:
    results = json.load(fp)

df = {
    k: [res["parameters"][k] for res in results]
    for k in results[0]["parameters"].keys()
}
df["score"] = [res["score"] for res in results]
df["std"] = [res["std"] for res in results]
df["loss"] = [res["loss"] for res in results]

df = pd.DataFrame(df)
df = df[(df["score"] != -np.inf) & (df["score"] < 50)]
df
# Out:
#      hidden_layer_sizes  activation  learning_rate     lam  alpha       tol  \
# 0                   [3]    logistic           0.01  0.0000    0.0  0.000001
# 1                   [3]    logistic           0.01  0.0000    0.0  0.000001
# 2                   [3]    logistic           0.01  0.0000    0.0  0.000001
# 3                   [3]    logistic           0.01  0.0000    0.0  0.000001
# 4                   [3]    logistic           0.01  0.0000    0.0  0.000001
# ...                 ...         ...            ...     ...    ...       ...
# 3067                [3]  leaky_relu           0.30  0.0001    0.9  0.000001
# 3068                [3]  leaky_relu           0.30  0.0001    0.9  0.000001
# 3069                [3]  leaky_relu           0.30  0.0001    0.9  0.000001
# 3070                [3]  leaky_relu           0.30  0.0001    0.9  0.000001
# 3071                [3]  leaky_relu           0.30  0.0001    0.9  0.000001
#
#       batch_size  shuffle  early_stopping  max_iter     score       std  \
# 0             16    False           False      2000  0.480128  0.241037
# 1             16    False            True      2000  0.322436  0.279285
# 2             16     True           False      2000  0.518590  0.232127
# 3             16     True            True      2000  0.592949  0.317631
# 4             32    False           False      2000  0.326923  0.181920
# ...          ...      ...             ...       ...       ...       ...
# 3067           8     True            True      2000  0.632051  0.364294
# 3068          16    False           False      2000  0.796795  0.229842
# 3069          16    False            True      2000  0.597436  0.347266
# 3070          16     True           False      2000  0.739103  0.295805
# 3071          16     True            True      2000  0.623077  0.284846
#
#           loss
# 0     0.170747
# 1     0.230486
# 2     0.170084
# 3     0.240103
# 4     0.220352
# ...        ...
# 3067  0.117159
# 3068  0.012098
# 3069  0.153193
# 3070  0.014018
# 3071  0.160488
#
# [3072 rows x 13 columns]

# %%
from plotting import param_boxplot


for k in df.columns:
    if k != "score" and k != "std" and k != "loss":
        param_boxplot(df, k)
